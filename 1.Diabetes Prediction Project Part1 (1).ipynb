# %% [markdown]
# #    EDA For DIABETES PREDICTION

# %% [markdown]
# ## Importing the Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing Dataset

# %%
dp=pd.read_csv("diabetes.csv")

# %%
dp
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
dp.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
dp.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
dp.shape
# Out:
# (768, 9)

# %%
dp.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# ## 1.Variable Identification

# %% [markdown]
# ### Dependent Variable
#     Outcome

# %% [markdown]
# ### Independent Variables
#
#     1.Pregnancies
#     2.Gllucose
#     3.BloodPressure
#     4.SkinThickness
#     5.Insulin
#     6.BMI
#     7.DiabetesPidegreeFunction
#     8.Age

# %%
dp.info() #iexist or nott will shows the datatypes present in the dataset and also shows null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# ### Data Types
#
# ### Integer:
#     Pregnancies
#     Age
#     Outcome
# ### Float:
#     BMI
#     Glucose
#     BloodPressure
#     SkinThickness
#     Insulin
#     DiabetesPedigreeFunction

# %%
dp.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ### Variable Category:
# #### Categorical:
#     Outcome
# #### Discreet:
# #### Continious:
#     Age
#     Pregnancies
#     Glucose
#     BloodPressure
#     Skin Thickness
#     Insulin
#     BMI
#     DiabetesPedigreeFunction

# %% [markdown]
# ### Step:2 Univariate Analysis
#     for Categorical:
#         Use Countplot

# %%
sns.countplot(x='Outcome',data=dp)#it is used for analysing purpose
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='count'>

# %% [markdown]
# ## Continious Variable
#     Use Boxplot

# %% [markdown]
# ###  -->Age
# <br>

# %%
sns.boxplot(y="Age",data=dp)## it is used to see the outliers
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
sns.distplot(dp["Age"],bins=10)
# Out:
# c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## Observation:
#
#     Maximum People Lies in range of - 21.0 to 40.0
#     Min Value is 21.0
#     Mean is 33.24

# %% [markdown]
# ### -->Body Mass Index(BMI)
# <br>

# %%
sns.boxplot(y="BMI",data=dp)
# Out:
# <AxesSubplot:ylabel='BMI'>

# %%
sns.distplot(dp["BMI"],bins=10)
# Out:
# c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='BMI', ylabel='Density'>

# %% [markdown]
# ## Observation:
#
#     Maximum People Lies in rangen of - 20 to 40
#     Min Value is 0

# %% [markdown]
# ### -->DiabetesPedigreeFunction(DPF)
# <br>

# %%
sns.boxplot(y="DiabetesPedigreeFunction",data=dp)
# Out:
# <AxesSubplot:ylabel='DiabetesPedigreeFunction'>

# %%
sns.distplot(dp["DiabetesPedigreeFunction"],bins=10)
# Out:
# c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='DiabetesPedigreeFunction', ylabel='Density'>

# %% [markdown]
# ## Observation:
#
#     Maximum People Lies in rangen of - 0.08 to 0.5
#     Min Value is 0.08
#     Mean is 0.47

# %% [markdown]
# ### -->Blood Pressure(BP)
# <br>

# %%
sns.boxplot(y="BloodPressure",data=dp)
# Out:
# <AxesSubplot:ylabel='BloodPressure'>

# %%
sns.distplot(dp["BloodPressure"],bins=10)
# Out:
# c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='BloodPressure', ylabel='Density'>

# %% [markdown]
# ## Observation:
#
#     Maximum People Lies in rangen of - 65 to 100
#     Min Value is 0

# %% [markdown]
# ### -->Glucose
# <br>

# %%
sns.boxplot(y="Glucose",data=dp)
# Out:
# <AxesSubplot:ylabel='Glucose'>

# %%
sns.distplot(dp["Glucose"],bins=10)
# Out:
# c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Glucose', ylabel='Density'>

# %% [markdown]
# ## Observation:
#
#     Maximum People Lies in rangen of - 100 to 140
#     Min Value is 0

# %% [markdown]
# ### -->Insulin
# <br>

# %%
sns.boxplot(y="Insulin",data=dp)
# Out:
# <AxesSubplot:ylabel='Insulin'>

# %%
sns.distplot(dp["Insulin"],bins=10)
# Out:
# c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Insulin', ylabel='Density'>

# %% [markdown]
# ## Observation:
#
#     Maximum People Lies in rangen of - 0 to 400
#     Min Value is 0

# %% [markdown]
# ### -->Pregnancies
# <br>

# %%
sns.boxplot(y="Pregnancies",data=dp)
# Out:
# <AxesSubplot:ylabel='Pregnancies'>

# %%
sns.distplot(dp["Pregnancies"],bins=10)
# Out:
# c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Pregnancies', ylabel='Density'>

# %% [markdown]
# ## Observation:
#
#     Maximum People Lies in rangen of - 0 to 5
#     Mean is 3.85
#     Max is 17

# %% [markdown]
# ### -->Skin Thickness
# <br>

# %%
sns.boxplot(y="SkinThickness",data=dp)
# Out:
# <AxesSubplot:ylabel='SkinThickness'>

# %%
sns.distplot(dp["SkinThickness"],bins=10)
# Out:
# c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SkinThickness', ylabel='Density'>

# %% [markdown]
# ## Observation:
#
#     Mean is 20.54
#     min values is 0
#     max value is 99

# %% [markdown]
# ### Bivariate Analysis
#
#     a.Continous & Continuous--Scatter Plot
#     b.Continous & Categorical
#     c.Categorical & Categorical
#
# ### Variable Category:
# <h4>Categorical</h4>
#
#     Outcome
#
# <h4>Continious</h4>
#
#     Age
#     Pregnancies
#     Glucose
#     BloodPressure
#     Skin Thickness
#     Insulin
#     BMI
#     DiabetesPedigreeFunction

# %%
dp_con=dp.iloc[:,:-1]
sns.pairplot(dp_con)

# %%
dp_con1=dp.iloc[::-1]
sns.pairplot(dp_con1)

# %%
dp_con2=dp.iloc[:-1]
sns.pairplot(dp_con2)

# %%
sns.heatmap(dp.corr(),annot=True,linewidth=0.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Step 4: Missing Values Treatment

# %%
dp.isnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# 1                       False  False    False
# 2                       False  False    False
# 3                       False  False    False
# 4                       False  False    False
# ..                        ...    ...      ...
# 763                     False  False    False
# 764                     False  False    False
# 765                     False  False    False
# 766                     False  False    False
# 767                     False  False    False
#
# [768 rows x 9 columns]

# %%
dp.isnull().values.any()
# Out:
# False

# %%
dp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
dp.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
dp
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
print(dp[dp["Glucose"]==0].shape[0])
# Out:
# 5

# %%
print(dp[dp["Insulin"]==0].shape[0])
# Out:
# 374

# %%
print(dp[dp["SkinThickness"]==0].shape[0])
# Out:
# 227

# %%
print(dp[dp["BMI"]==0].shape[0])
# Out:
# 11

# %%
print(dp[dp["BloodPressure"]==0].shape[0])
# Out:
# 35

# %%
dp["Insulin"]=dp["Insulin"].replace(0,dp["Insulin"].mean())

# %%
dp["SkinThickness"]=dp["SkinThickness"].replace(0,dp["SkinThickness"].mean())

# %%
dp["BMI"]=dp["BMI"].replace(0,dp["BMI"].median())

# %%
dp["Glucose"]=dp["Glucose"].replace(0,dp["Glucose"].median())

# %%
dp["BloodPressure"]=dp["BloodPressure"].replace(0,dp["BloodPressure"].mean())

# %% [markdown]
# <html>
#     <h3> Observation</h3>
#     <p>It is showing clearly there is <b>No Null Values</b> in the Give diabates Dataset</p>
# </html>

# %%
dp
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6    148.0           72.0      35.000000   79.799479  33.6
# 1              1     85.0           66.0      29.000000   79.799479  26.6
# 2              8    183.0           64.0      20.536458   79.799479  23.3
# 3              1     89.0           66.0      23.000000   94.000000  28.1
# 4              0    137.0           40.0      35.000000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10    101.0           76.0      48.000000  180.000000  32.9
# 764            2    122.0           70.0      27.000000   79.799479  36.8
# 765            5    121.0           72.0      23.000000  112.000000  26.2
# 766            1    126.0           60.0      20.536458   79.799479  30.1
# 767            1     93.0           70.0      31.000000   79.799479  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %% [markdown]
# <html>
#      <h3>Step 5: Outliers Detection and Recovery</h3>
#         <p>we already <b>detect Outliers</b> at Univariate Analasis</p>
# </html>

# %% [markdown]
# ##### Age

# %%
dp["Age"].describe()
# Out:
# count    768.00000
# mean      33.10026
# std       11.37607
# min       21.00000
# 25%       24.00000
# 50%       29.00000
# 75%       41.00000
# max       66.00000
# Name: Age, dtype: float64

# %%
IQR = dp['Age'].quantile(0.75)-dp['Age'].quantile(0.25) 
print(IQR)
# Out:
# 17.0

# %%
Upper_OutlierLimit = dp['Age'].quantile(0.75) + 1.5*IQR
Lower_OutlierLimit = dp['Age'].quantile(0.25) - 1.5*IQR 
print(Upper_OutlierLimit)
print(Lower_OutlierLimit)
# Out:
# 66.5
# -1.5

# %%
OutlierValues = dp[(dp['Age']>=Upper_OutlierLimit) | (dp[ 'Age']<=Lower_OutlierLimit)]

# %%
OutlierValues
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness    Insulin   BMI  \
# 123            5    132.0      80.000000      20.536458  79.799479  26.8
# 363            4    146.0      78.000000      20.536458  79.799479  38.5
# 453            2    119.0      69.105469      20.536458  79.799479  19.6
# 459            9    134.0      74.000000      33.000000  60.000000  25.9
# 489            8    194.0      80.000000      20.536458  79.799479  26.1
# 537            0     57.0      60.000000      20.536458  79.799479  21.7
# 666            4    145.0      82.000000      18.000000  79.799479  32.5
# 674            8     91.0      82.000000      20.536458  79.799479  35.6
# 684            5    136.0      82.000000      20.536458  79.799479  32.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 123                     0.186   69        0
# 363                     0.520   67        1
# 453                     0.832   72        0
# 459                     0.460   81        0
# 489                     0.551   67        0
# 537                     0.735   67        0
# 666                     0.235   70        1
# 674                     0.587   68        0
# 684                     0.640   69        0

# %%
dp.boxplot('Age')
# Out:
# <AxesSubplot:>

# %%
for i in OutlierValues.index:
    print(i,end=",")
    dp['Age'][i]=dp['Age'].quantile(0.95)
# Out:
# 123,363,453,459,489,537,666,674,684,
# <ipython-input-53-e504ca96408b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dp['Age'][i]=dp['Age'].quantile(0.95)

# %%
print(OutlierValues.index)
# Out:
# Int64Index([123, 363, 453, 459, 489, 537, 666, 674, 684], dtype='int64')

# %%
dp.boxplot('Age')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Observation:
#     As you see above boxplot there is no Outliers

# %% [markdown]
# ### Body Mass Index(BMI)
# <br>

# %%
dp.boxplot("BMI")
# Out:
# <AxesSubplot:>

# %%
dp['BMI'].describe()
# Out:
# count    768.000000
# mean      32.450911
# std        6.875366
# min       18.200000
# 25%       27.500000
# 50%       32.000000
# 75%       36.600000
# max       67.100000
# Name: BMI, dtype: float64

# %%
IQR = dp['BMI'].quantile(0.75)-dp['BMI'].quantile(0.25) 
print(IQR)
# Out:
# 9.100000000000001

# %%
Upper_OutlierLimit = dp['BMI'].quantile(0.70) + 1.5*IQR
Lower_OutlierLimit = dp['BMI'].quantile(0.30) - 1.5*IQR 
 
print(Upper_OutlierLimit)
print(Lower_OutlierLimit)
# Out:
# 49.14
# 14.849999999999998

# %%
OutlierValues = dp[(dp['BMI']>=Upper_OutlierLimit) | (dp[ 'BMI']<=Lower_OutlierLimit)] 
OutlierValues
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 99             1    122.0      90.000000      51.000000  220.000000  49.7
# 120            0    162.0      76.000000      56.000000  100.000000  53.2
# 125            1     88.0      30.000000      42.000000   99.000000  55.0
# 155            7    152.0      88.000000      44.000000   79.799479  50.0
# 177            0    129.0     110.000000      46.000000  130.000000  67.1
# 193           11    135.0      69.105469      20.536458   79.799479  52.3
# 247            0    165.0      90.000000      33.000000  680.000000  52.3
# 303            5    115.0      98.000000      20.536458   79.799479  52.9
# 445            0    180.0      78.000000      63.000000   14.000000  59.4
# 673            3    123.0     100.000000      35.000000  240.000000  57.3
# 681            0    162.0      76.000000      36.000000   79.799479  49.6
# 746            1    147.0      94.000000      41.000000   79.799479  49.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 99                      0.325   31        1
# 120                     0.759   25        1
# 125                     0.496   26        1
# 155                     0.337   36        1
# 177                     0.319   26        1
# 193                     0.578   40        1
# 247                     0.427   23        0
# 303                     0.209   28        1
# 445                     2.420   25        1
# 673                     0.880   22        0
# 681                     0.364   26        1
# 746                     0.358   27        1

# %%
for i in OutlierValues.index:
    print(i,end=",")
    dp['BMI'][i]=dp['BMI'].quantile(0.95)

print(OutlierValues.index)
# Out:
# 99,120,125,155,177,193,247,303,445,673,681,746,Int64Index([99, 120, 125, 155, 177, 193, 247, 303, 445, 673, 681, 746], dtype='int64')
# <ipython-input-61-7db3014f8fff>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dp['BMI'][i]=dp['BMI'].quantile(0.95)

# %%
dp.boxplot("BMI")
# Out:
# <AxesSubplot:>

# %% [markdown]
# <html>
#      <h3>Observation:</h3>
#         <p>when you observe Above Boxplot it will shows the is <b>No outliers</b> in BMI</p>
# </html>

# %% [markdown]
# ### DiabetesPedigreeFunction(DPF)
# <br>

# %%
dp.boxplot("DiabetesPedigreeFunction")
# Out:
# <AxesSubplot:>

# %%
dp['DiabetesPedigreeFunction'].describe()
# Out:
# count    768.000000
# mean       0.471876
# std        0.331329
# min        0.078000
# 25%        0.243750
# 50%        0.372500
# 75%        0.626250
# max        2.420000
# Name: DiabetesPedigreeFunction, dtype: float64

# %%
IQR = dp['DiabetesPedigreeFunction'].quantile(0.75)-dp['DiabetesPedigreeFunction'].quantile(0.25) 
print(IQR)
# Out:
# 0.38249999999999995

# %%
Upper_OutlierLimit = dp['DiabetesPedigreeFunction'].quantile(0.75) + 1.5*IQR
Lower_OutlierLimit = dp['DiabetesPedigreeFunction'].quantile(0.25) - 1.5*IQR 
 
print(Upper_OutlierLimit)
print(Lower_OutlierLimit)
# Out:
# 1.2
# -0.32999999999999996

# %%
OutlierValues = dp[(dp['DiabetesPedigreeFunction']>=Upper_OutlierLimit) | (dp[ 'DiabetesPedigreeFunction']<=Lower_OutlierLimit)]

# %%
OutlierValues
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin  \
# 4              0    137.0           40.0      35.000000  168.000000
# 12            10    139.0           80.0      20.536458   79.799479
# 39             4    111.0           72.0      47.000000  207.000000
# 45             0    180.0           66.0      39.000000   79.799479
# 58             0    146.0           82.0      20.536458   79.799479
# 100            1    163.0           72.0      20.536458   79.799479
# 147            2    106.0           64.0      35.000000  119.000000
# 187            1    128.0           98.0      41.000000   58.000000
# 218            5     85.0           74.0      22.000000   79.799479
# 228            4    197.0           70.0      39.000000  744.000000
# 243            6    119.0           50.0      22.000000  176.000000
# 245            9    184.0           85.0      15.000000   79.799479
# 259           11    155.0           76.0      28.000000  150.000000
# 292            2    128.0           78.0      37.000000  182.000000
# 308            0    128.0           68.0      19.000000  180.000000
# 330            8    118.0           72.0      19.000000   79.799479
# 370            3    173.0           82.0      48.000000  465.000000
# 371            0    118.0           64.0      23.000000   89.000000
# 383            1     90.0           62.0      18.000000   59.000000
# 395            2    127.0           58.0      24.000000  275.000000
# 445            0    180.0           78.0      63.000000   14.000000
# 534            1     77.0           56.0      30.000000   56.000000
# 593            2     82.0           52.0      22.000000  115.000000
# 606            1    181.0           78.0      42.000000  293.000000
# 618            9    112.0           82.0      24.000000   79.799479
# 621            2     92.0           76.0      20.000000   79.799479
# 622            6    183.0           94.0      20.536458   79.799479
# 659            3     80.0           82.0      31.000000   70.000000
# 661            1    199.0           76.0      43.000000   79.799479
#
#            BMI  DiabetesPedigreeFunction  Age  Outcome
# 4    43.100000                     2.288   33        1
# 12   27.100000                     1.441   57        0
# 39   37.100000                     1.390   56        1
# 45   42.000000                     1.893   25        1
# 58   40.500000                     1.781   44        0
# 100  39.000000                     1.222   33        1
# 147  30.500000                     1.400   34        0
# 187  32.000000                     1.321   33        1
# 218  29.000000                     1.224   32        1
# 228  36.700000                     2.329   31        0
# 243  27.100000                     1.318   33        1
# 245  30.000000                     1.213   49        1
# 259  33.300000                     1.353   51        1
# 292  43.300000                     1.224   31        1
# 308  30.500000                     1.391   25        1
# 330  23.100000                     1.476   46        0
# 370  38.400000                     2.137   25        1
# 371  32.000000                     1.731   21        0
# 383  25.100000                     1.268   25        0
# 395  27.700000                     1.600   25        0
# 445  44.206214                     2.420   25        1
# 534  33.300000                     1.251   24        0
# 593  28.500000                     1.699   25        0
# 606  40.000000                     1.258   22        1
# 618  28.200000                     1.282   50        1
# 621  24.200000                     1.698   28        0
# 622  40.800000                     1.461   45        0
# 659  34.200000                     1.292   27        1
# 661  42.900000                     1.394   22        1

# %%
for i in OutlierValues.index:
    print(i,end=",")
    dp['DiabetesPedigreeFunction'][i]=dp['DiabetesPedigreeFunction'].quantile(0.95)
print(OutlierValues.index)
# Out:
# 4,12,39,45,58,100,147,187,218,228,243,245,259,292,308,330,370,371,383,395,445,534,593,606,618,621,622,659,661,Int64Index([  4,  12,  39,  45,  58, 100, 147, 187, 218, 228, 243, 245, 259,
#             292, 308, 330, 370, 371, 383, 395, 445, 534, 593, 606, 618, 621,
#             622, 659, 661],
#            dtype='int64')
# <ipython-input-69-d3b4620e9bb0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dp['DiabetesPedigreeFunction'][i]=dp['DiabetesPedigreeFunction'].quantile(0.95)

# %%
dp.boxplot("DiabetesPedigreeFunction")
# Out:
# <AxesSubplot:>

# %% [markdown]
# <html>
#      <h3>Observation:</h3>
#         <p>when you observe Above Boxplot it will shows the is <b>No outliers</b> in DiabetesPedigreeFunction</p>
# </html>

# %% [markdown]
# ### Blood Pressure(BP)
# <br>

# %%
dp.boxplot("BloodPressure")
# Out:
# <AxesSubplot:>

# %%
dp["BloodPressure"].describe()
# Out:
# count    768.000000
# mean      72.254807
# std       12.115932
# min       24.000000
# 25%       64.000000
# 50%       72.000000
# 75%       80.000000
# max      122.000000
# Name: BloodPressure, dtype: float64

# %%
IQR = dp['BloodPressure'].quantile(0.75)-dp['BloodPressure'].quantile(0.25) 
print("IQR=",IQR) 

Upper_OutlierLimit = dp['BloodPressure'].quantile(0.75) + 1.5*IQR
Lower_OutlierLimit = dp['BloodPressure'].quantile(0.25) - 1.5*IQR 
 
print("Upper_OutlierLimit",Upper_OutlierLimit)
print("Lower_OutlierLimit",Lower_OutlierLimit)
# Out:
# IQR= 16.0
# Upper_OutlierLimit 104.0
# Lower_OutlierLimit 40.0

# %%
OutlierValues = dp[(dp['BloodPressure']>=Upper_OutlierLimit) | (dp[ 'BloodPressure']<=Lower_OutlierLimit)]

# %%
for i in OutlierValues.index:
    print(i,end=",")
    dp['BloodPressure'][i]=dp['BloodPressure'].quantile(0.95)
print(OutlierValues.index)
# Out:
# 4,18,43,84,106,125,177,207,362,440,549,597,599,658,662,672,691,Int64Index([4, 18, 43, 84, 106, 125, 177, 207, 362, 440, 549, 597, 599, 658,
#             662, 672, 691],
#            dtype='int64')
# <ipython-input-75-657fa1997a01>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dp['BloodPressure'][i]=dp['BloodPressure'].quantile(0.95)

# %%
dp.boxplot("BloodPressure")
# Out:
# <AxesSubplot:>

# %% [markdown]
# <html>
#     <h3>Observation:</h3>
#         <p>when you oberserve above boxplot it is showing there is <b>No Outilers</b>in BloodPressure</p>
# </html>

# %% [markdown]
# ### Glucose
# <br>

# %%
dp.boxplot("Glucose")
# Out:
# <AxesSubplot:>

# %%
dp["Glucose"].describe()
# Out:
# count    768.000000
# mean     121.656250
# std       30.438286
# min       44.000000
# 25%       99.750000
# 50%      117.000000
# 75%      140.250000
# max      199.000000
# Name: Glucose, dtype: float64

# %%
IQR = dp['Glucose'].quantile(0.75)-dp['Glucose'].quantile(0.25) 
print("IQR=",IQR) 

Upper_OutlierLimit = dp['Glucose'].quantile(0.75) + 1.5*IQR
Lower_OutlierLimit = dp['Glucose'].quantile(0.25) - 1.5*IQR 
 
print("Upper_OutlierLimit",Upper_OutlierLimit)
print("Lower_OutlierLimit",Lower_OutlierLimit)
# Out:
# IQR= 40.5
# Upper_OutlierLimit 201.0
# Lower_OutlierLimit 39.0

# %%
OutlierValues = dp[(dp['Glucose']>=Upper_OutlierLimit) | (dp[ 'Glucose']<=Lower_OutlierLimit)]

# %%
for i in OutlierValues.index:
    print(i,end=",")
    dp['Glucose'][i]=dp['Glucose'].quantile(0.95)
print(OutlierValues.index)
# Out:
# Int64Index([], dtype='int64')

# %%
dp.boxplot("Glucose")
# Out:
# <AxesSubplot:>

# %% [markdown]
# <html>
#     <h3>Observation:</h3>
#         <p>when you oberserve above boxplot it is showing there is Glucose has <b>No Outilers</b></p>
# </html>

# %% [markdown]
# ### Insulin
# <br>

# %%
dp.boxplot("Insulin")
# Out:
# <AxesSubplot:>

# %%
dp["Insulin"].describe()
# Out:
# count    768.000000
# mean     118.660163
# std       93.080358
# min       14.000000
# 25%       79.799479
# 50%       79.799479
# 75%      127.250000
# max      846.000000
# Name: Insulin, dtype: float64

# %%
IQR = dp['Insulin'].quantile(0.75)-dp['Insulin'].quantile(0.25) 
print("IQR=",IQR) 

Upper_OutlierLimit = dp['Insulin'].quantile(0.75) + 1.5*IQR
Lower_OutlierLimit = dp['Insulin'].quantile(0.25) - 1.5*IQR 
 
print("Upper_OutlierLimit",Upper_OutlierLimit)
print("Lower_OutlierLimit",Lower_OutlierLimit)
# Out:
# IQR= 47.45052083333333
# Upper_OutlierLimit 198.42578125
# Lower_OutlierLimit 8.623697916666671

# %%
OutlierValues = dp[(dp['Insulin']>=Upper_OutlierLimit) | (dp[ 'Insulin']<=Lower_OutlierLimit)] 
OutlierValues
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 8              2    197.0           70.0           45.0    543.0  30.5
# 13             1    189.0           60.0           23.0    846.0  30.1
# 16             0    118.0           84.0           47.0    230.0  45.8
# 20             3    126.0           88.0           41.0    235.0  39.3
# 31             3    158.0           76.0           36.0    245.0  31.6
# ..           ...      ...            ...            ...      ...   ...
# 713            0    134.0           58.0           20.0    291.0  26.4
# 715            7    187.0           50.0           33.0    392.0  33.9
# 721            1    114.0           66.0           36.0    200.0  38.1
# 748            3    187.0           70.0           22.0    200.0  36.4
# 753            0    181.0           88.0           44.0    510.0  43.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 8                       0.158   53        1
# 13                      0.398   59        1
# 16                      0.551   31        1
# 20                      0.704   27        0
# 31                      0.851   28        1
# ..                        ...  ...      ...
# 713                     0.352   21        0
# 715                     0.826   34        1
# 721                     0.289   21        0
# 748                     0.408   36        1
# 753                     0.222   26        1
#
# [89 rows x 9 columns]

# %%
for i in OutlierValues.index:
    print(i,end=",")
    dp['Insulin'][i]=dp['Insulin'].quantile(0.95)
print(OutlierValues.index)
# Out:
# 8,13,16,20,31,39,43,53,54,56,73,95,99,111,132,139,144,150,153,162,186,195,199,206,215,220,228,231,247,248,254,258,279,286,287,296,297,309,320,335,359,360,364,370,
# <ipython-input-87-125c60e70d34>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dp['Insulin'][i]=dp['Insulin'].quantile(0.95)
# 375,388,392,395,409,412,415,424,425,452,458,480,485,486,487,511,519,538,540,545,546,555,561,574,584,594,606,608,612,645,655,657,662,673,679,685,695,700,707,710,713,715,721,748,753,Int64Index([  8,  13,  16,  20,  31,  39,  43,  53,  54,  56,  73,  95,  99,
#             111, 132, 139, 144, 150, 153, 162, 186, 195, 199, 206, 215, 220,
#             228, 231, 247, 248, 254, 258, 279, 286, 287, 296, 297, 309, 320,
#             335, 359, 360, 364, 370, 375, 388, 392, 395, 409, 412, 415, 424,
#             425, 452, 458, 480, 485, 486, 487, 511, 519, 538, 540, 545, 546,
#             555, 561, 574, 584, 594, 606, 608, 612, 645, 655, 657, 662, 673,
#             679, 685, 695, 700, 707, 710, 713, 715, 721, 748, 753],
#            dtype='int64')

# %%
dp.boxplot("Insulin")
# Out:
# <AxesSubplot:>

# %% [markdown]
# <html>
#     <h3>Observation:</h3>
#         <p>when you oberserve above boxplot it is showing there is <b>No Outilers</b> in Insulin</p>
# </html>

# %% [markdown]
# ### Pregnancies
#   <br>

# %%
dp.boxplot("Pregnancies")
# Out:
# <AxesSubplot:>

# %%
dp["Pregnancies"].describe()
# Out:
# count    768.000000
# mean       3.845052
# std        3.369578
# min        0.000000
# 25%        1.000000
# 50%        3.000000
# 75%        6.000000
# max       17.000000
# Name: Pregnancies, dtype: float64

# %%
IQR = dp['Pregnancies'].quantile(0.75)-dp['Pregnancies'].quantile(0.25) 
print("IQR=",IQR) 

Upper_OutlierLimit = dp['Pregnancies'].quantile(0.75) + 1.5*IQR
Lower_OutlierLimit = dp['Pregnancies'].quantile(0.25) - 1.5*IQR 
 
print("Upper_OutlierLimit",Upper_OutlierLimit)
print("Lower_OutlierLimit",Lower_OutlierLimit)
# Out:
# IQR= 5.0
# Upper_OutlierLimit 13.5
# Lower_OutlierLimit -6.5

# %%
OutlierValues = dp[(dp['Pregnancies']>=Upper_OutlierLimit) | (dp[ 'Pregnancies']<=Lower_OutlierLimit)] 
OutlierValues
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 88            15    136.0           70.0           32.0  110.000000  37.1
# 159           17    163.0           72.0           41.0  114.000000  40.9
# 298           14    100.0           78.0           25.0  184.000000  36.6
# 455           14    175.0           62.0           30.0   79.799479  33.6
#
#      DiabetesPedigreeFunction  Age  Outcome
# 88                      0.153   43        1
# 159                     0.817   47        1
# 298                     0.412   46        1
# 455                     0.212   38        1

# %%
for i in OutlierValues.index:
    print(i,end=",")
    dp['Pregnancies'][i]=dp['Pregnancies'].quantile(0.95)
print(OutlierValues.index)
# Out:
# 88,159,298,455,Int64Index([88, 159, 298, 455], dtype='int64')
# <ipython-input-93-9132d7b60fa7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dp['Pregnancies'][i]=dp['Pregnancies'].quantile(0.95)

# %%
dp.boxplot("Pregnancies")
# Out:
# <AxesSubplot:>

# %% [markdown]
# <html>
#     <h3>Observation:</h3>
#         <p>when you oberserve above boxplot it is showing there is <b>No Outilers</b>in Pregnancies</p>
# </html>

# %% [markdown]
# ### Skin Thickness
# <br>

# %%
dp.boxplot("SkinThickness")
# Out:
# <AxesSubplot:>

# %%
dp["SkinThickness"].describe()
# Out:
# count    768.000000
# mean      26.606479
# std        9.631241
# min        7.000000
# 25%       20.536458
# 50%       23.000000
# 75%       32.000000
# max       99.000000
# Name: SkinThickness, dtype: float64

# %%
IQR = dp['SkinThickness'].quantile(0.75)-dp['SkinThickness'].quantile(0.25) 
print("IQR=",IQR) 

Upper_OutlierLimit = dp['SkinThickness'].quantile(0.75) + 1.5*IQR
Lower_OutlierLimit = dp['SkinThickness'].quantile(0.25) - 1.5*IQR 
 
print("Upper_OutlierLimit",Upper_OutlierLimit)
print("Lower_OutlierLimit",Lower_OutlierLimit)
# Out:
# IQR= 11.463541666666668
# Upper_OutlierLimit 49.1953125
# Lower_OutlierLimit 3.341145833333332

# %%
OutlierValues = dp[(dp['SkinThickness']>=Upper_OutlierLimit) | (dp[ 'SkinThickness']<=Lower_OutlierLimit)] 
OutlierValues
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin  \
# 57             0    100.0           88.0           60.0  110.000000
# 86            13    106.0           72.0           54.0   79.799479
# 99             1    122.0           90.0           51.0  293.000000
# 120            0    162.0           76.0           56.0  100.000000
# 150            1    136.0           74.0           50.0  293.000000
# 211            0    147.0           85.0           54.0   79.799479
# 273            1     71.0           78.0           50.0   45.000000
# 275            2    100.0           70.0           52.0   57.000000
# 445            0    180.0           78.0           63.0   14.000000
# 532            1     86.0           66.0           52.0   65.000000
# 579            2    197.0           70.0           99.0   79.799479
# 591            2    112.0           78.0           50.0  140.000000
#
#            BMI  DiabetesPedigreeFunction  Age  Outcome
# 57   46.800000                  0.962000   31        0
# 86   36.600000                  0.178000   45        0
# 99   44.395000                  0.325000   31        1
# 120  44.326750                  0.759000   25        1
# 150  37.400000                  0.399000   24        0
# 211  42.800000                  0.375000   24        0
# 273  33.200000                  0.422000   21        0
# 275  40.500000                  0.677000   25        0
# 445  44.206214                  1.127001   25        1
# 532  41.300000                  0.917000   29        0
# 579  34.700000                  0.575000   62        1
# 591  39.400000                  0.175000   24        0

# %%
for i in OutlierValues.index:
    print(i,end=",")
    dp['SkinThickness'][i]=dp['SkinThickness'].quantile(0.95)
print(OutlierValues.index)
# Out:
# 57,86,99,120,150,211,273,275,445,532,579,591,Int64Index([57, 86, 99, 120, 150, 211, 273, 275, 445, 532, 579, 591], dtype='int64')
# <ipython-input-99-7bb5c4c6e2de>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dp['SkinThickness'][i]=dp['SkinThickness'].quantile(0.95)

# %%
dp.boxplot("SkinThickness")
# Out:
# <AxesSubplot:>

# %%
OutlierValues = dp[(dp['SkinThickness']>=Upper_OutlierLimit) | (dp[ 'SkinThickness']<=Lower_OutlierLimit)] 
OutlierValues
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %% [markdown]
# <html>
#     <h3>Observation:</h3>
#         <p>when you oberserve above boxplot it is showing there is <b>No Outilers</b> in SkinThickness</p>
# </html>

# %%
dp
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6    148.0           72.0      35.000000   79.799479  33.6
# 1              1     85.0           66.0      29.000000   79.799479  26.6
# 2              8    183.0           64.0      20.536458   79.799479  23.3
# 3              1     89.0           66.0      23.000000   94.000000  28.1
# 4              0    137.0           90.0      35.000000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10    101.0           76.0      48.000000  180.000000  32.9
# 764            2    122.0           70.0      27.000000   79.799479  36.8
# 765            5    121.0           72.0      23.000000  112.000000  26.2
# 766            1    126.0           60.0      20.536458   79.799479  30.1
# 767            1     93.0           70.0      31.000000   79.799479  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                     0.62700   50        1
# 1                     0.35100   31        0
# 2                     0.67200   32        1
# 3                     0.16700   21        0
# 4                     1.13285   33        1
# ..                        ...  ...      ...
# 763                   0.17100   63        0
# 764                   0.34000   27        0
# 765                   0.24500   30        0
# 766                   0.34900   47        1
# 767                   0.31500   23        0
#
# [768 rows x 9 columns]

# %%
dp.boxplot("Glucose")
# Out:
# <AxesSubplot:>

# %%
dp
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6    148.0           72.0      35.000000   79.799479  33.6
# 1              1     85.0           66.0      29.000000   79.799479  26.6
# 2              8    183.0           64.0      20.536458   79.799479  23.3
# 3              1     89.0           66.0      23.000000   94.000000  28.1
# 4              0    137.0           90.0      35.000000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10    101.0           76.0      48.000000  180.000000  32.9
# 764            2    122.0           70.0      27.000000   79.799479  36.8
# 765            5    121.0           72.0      23.000000  112.000000  26.2
# 766            1    126.0           60.0      20.536458   79.799479  30.1
# 767            1     93.0           70.0      31.000000   79.799479  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                     0.62700   50        1
# 1                     0.35100   31        0
# 2                     0.67200   32        1
# 3                     0.16700   21        0
# 4                     1.13285   33        1
# ..                        ...  ...      ...
# 763                   0.17100   63        0
# 764                   0.34000   27        0
# 765                   0.24500   30        0
# 766                   0.34900   47        1
# 767                   0.31500   23        0
#
# [768 rows x 9 columns]

# %%
cols=["Pregnancies","Glucose","BloodPressure","SkinThickness","Insulin","BMI","DiabetesPedigreeFunction","Age","Outcome"]
tp1=dp[cols]
tp1
tp1.to_csv("DiabetesPrediction444.csv")#i send the data set to titanic.xlsx
tp1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6    148.0           72.0      35.000000   79.799479  33.6
# 1              1     85.0           66.0      29.000000   79.799479  26.6
# 2              8    183.0           64.0      20.536458   79.799479  23.3
# 3              1     89.0           66.0      23.000000   94.000000  28.1
# 4              0    137.0           90.0      35.000000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10    101.0           76.0      48.000000  180.000000  32.9
# 764            2    122.0           70.0      27.000000   79.799479  36.8
# 765            5    121.0           72.0      23.000000  112.000000  26.2
# 766            1    126.0           60.0      20.536458   79.799479  30.1
# 767            1     93.0           70.0      31.000000   79.799479  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                     0.62700   50        1
# 1                     0.35100   31        0
# 2                     0.67200   32        1
# 3                     0.16700   21        0
# 4                     1.13285   33        1
# ..                        ...  ...      ...
# 763                   0.17100   63        0
# 764                   0.34000   27        0
# 765                   0.24500   30        0
# 766                   0.34900   47        1
# 767                   0.31500   23        0
#
# [768 rows x 9 columns]
